# %% [markdown]
# <a href="https://colab.research.google.com/github/jiannicello/pytorch_tutorial/blob/main/Intro_DeepL_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 + 2
# Out:
# 4

# %%
import torch
